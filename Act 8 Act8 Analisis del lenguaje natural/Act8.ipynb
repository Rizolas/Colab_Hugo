# %%
# !apt-get update -q
# !apt-get install -y chromium-browser chromium-driver -q
# !pip install selenium beautifulsoup4 textblob wordcloud webdriver_manager --quiet
# !python -m textblob.download_corpora --quiet

# %%
# !pip install google-colab-selenium --quiet

from google_colab_selenium import ChromeDriver

driver = ChromeDriver()
driver.get(URL)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 20.9 MB/s eta 0:00:00
#             <div class="spinner-container">
#                 <div class="spinner" id="90eb322d-e4d1-4079-bf3b-37629bb40dd2-circle"></div>
#                 <div class="spinner-text" id="90eb322d-e4d1-4079-bf3b-37629bb40dd2-text">Updating and upgrading APT</div>
#             </div>
#             <style>
#                 @keyframes spin {
#                     from { transform: rotate(0deg); }
#                     to { transform: rotate(360deg); }
#                 }
#
#                 .spinner-container {
#                     display: flex;
#                     align-items: center;
#                     margin-bottom: 3px;
#                 }
#
#                 .spinner {
#                     border: 3px solid rgba(0, 0, 0, 0.1);
#                     border-left-color: lightblue;
#                     border-radius: 50%;
#                     width: 12px;
#                     height: 12px;
#                     animation: spin 1s linear infinite;
#                 }
#
#                 .spinner-text {
#                     padding-left: 6px;
#                 }
#             </style>
#             <div class="spinner-container">
#                 <div class="spinner" id="c3e33005-3b65-43a3-a0eb-aaa9f6d6ace5-circle"></div>
#                 <div class="spinner-text" id="c3e33005-3b65-43a3-a0eb-aaa9f6d6ace5-text">Downloading Google Chrome</div>
#             </div>
#             <style>
#                 @keyframes spin {
#                     from { transform: rotate(0deg); }
#                     to { transform: rotate(360deg); }
#                 }
#
#                 .spinner-container {
#                     display: flex;
#                     align-items: center;
#                     margin-bottom: 3px;
#                 }
#
#                 .spinner {
#                     border: 3px solid rgba(0, 0, 0, 0.1);
#                     border-left-color: lightblue;
#                     border-radius: 50%;
#                     width: 12px;
#                     height: 12px;
#                     animation: spin 1s linear infinite;
#                 }
#
#                 .spinner-text {
#                     padding-left: 6px;
#                 }
#             </style>
#             <div class="spinner-container">
#                 <div class="spinner" id="14791e30-49b3-478b-8f95-a1afa1a65197-circle"></div>
#                 <div class="spinner-text" id="14791e30-49b3-478b-8f95-a1afa1a65197-text">Initializing Chromedriver</div>
#             </div>
#             <style>
#                 @keyframes spin {
#                     from { transform: rotate(0deg); }
#                     to { transform: rotate(360deg); }
#                 }
#
#                 .spinner-container {
#                     display: flex;
#                     align-items: center;
#                     margin-bottom: 3px;
#                 }
#
#                 .spinner {
#                     border: 3px solid rgba(0, 0, 0, 0.1);
#                     border-left-color: lightblue;
#                     border-radius: 50%;
#                     width: 12px;
#                     height: 12px;
#                     animation: spin 1s linear infinite;
#                 }
#
#                 .spinner-text {
#                     padding-left: 6px;
#                 }
#             </style>

# %%
URL          = "https://www.youtube.com/watch?v=OTlVmfO_j0Q"
MAX_COMMENTS = 40
SCROLL_PAUSE = 2.5

import time, re, json
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
from transformers import pipeline
from IPython.display import display, HTML
import pandas as pd

STAR_LABELS = {
    1: ("⭐",        "Muy Negativo / Odio"),
    2: ("⭐⭐",      "Negativo"),
    3: ("⭐⭐⭐",    "Neutral / Ambivalente"),
    4: ("⭐⭐⭐⭐",  "Positivo"),
    5: ("⭐⭐⭐⭐⭐","Muy Positivo / Excelente"),
}
# Out:
# ✅ Configuración lista

# %%
from google_colab_selenium import ChromeDriver

def get_driver():
    """Configura Chrome para Colab usando la librería especializada."""
    driver = ChromeDriver()
    return driver

def scrape_comments(url: str, max_comments: int) -> list:
    print("🚀 Abriendo Chrome headless...")
    driver = get_driver()
    driver.get(url)
    time.sleep(4)

    print("📜 Scrolleando para cargar comentarios...")
    comments_found = []

    for i in range(20):
        driver.execute_script("window.scrollBy(0, 800);")
        time.sleep(SCROLL_PAUSE)

        soup = BeautifulSoup(driver.page_source, "html.parser")
        comments_found = soup.find_all("yt-attributed-string", id="content-text")

        print(f"   Scroll {i+1:02d} → {len(comments_found)} comentarios encontrados")
        if len(comments_found) >= max_comments:
            break

    driver.quit()

    seen, clean = set(), []
    for tag in comments_found[:max_comments]:
        text = tag.get_text(separator=" ", strip=True)
        if text and len(text) > 3 and text not in seen:
            seen.add(text)
            clean.append(text)

    print(f"\n✅ {len(clean)} comentarios únicos extraídos")
    return clean


comments = scrape_comments(URL, MAX_COMMENTS)
# Out:
# 🚀 Abriendo Chrome headless...
#             <div class="spinner-container">
#                 <div class="spinner" id="69cbd5ce-5093-4460-b7cd-25c45742d243-circle"></div>
#                 <div class="spinner-text" id="69cbd5ce-5093-4460-b7cd-25c45742d243-text">Initializing Chromedriver</div>
#             </div>
#             <style>
#                 @keyframes spin {
#                     from { transform: rotate(0deg); }
#                     to { transform: rotate(360deg); }
#                 }
#
#                 .spinner-container {
#                     display: flex;
#                     align-items: center;
#                     margin-bottom: 3px;
#                 }
#
#                 .spinner {
#                     border: 3px solid rgba(0, 0, 0, 0.1);
#                     border-left-color: lightblue;
#                     border-radius: 50%;
#                     width: 12px;
#                     height: 12px;
#                     animation: spin 1s linear infinite;
#                 }
#
#                 .spinner-text {
#                     padding-left: 6px;
#                 }
#             </style>
# 📜 Scrolleando para cargar comentarios...
#    Scroll 01 → 0 comentarios encontrados
#    Scroll 02 → 0 comentarios encontrados
#    Scroll 03 → 0 comentarios encontrados
#    Scroll 04 → 0 comentarios encontrados
#    Scroll 05 → 19 comentarios encontrados
#    Scroll 06 → 19 comentarios encontrados
#    Scroll 07 → 19 comentarios encontrados
#    Scroll 08 → 39 comentarios encontrados
#    Scroll 09 → 39 comentarios encontrados
#    Scroll 10 → 39 comentarios encontrados
#    Scroll 11 → 39 comentarios encontrados
#    Scroll 12 → 56 comentarios encontrados
#
# ✅ 40 comentarios únicos extraídos

# %%
sentiment = pipeline(
    "text-classification",
    model="nlptown/bert-base-multilingual-uncased-sentiment",
    truncation=True,
    max_length=512,
)
# Out:
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]

# %%
print(" Analizando comentarios...\n")
results = []

for i, comment in enumerate(comments, 1):
    pred   = sentiment(comment)[0]
    stars  = int(re.search(r"(\d)", pred["label"]).group(1))
    score  = round(pred["score"] * 100, 2)
    emoji, label = STAR_LABELS[stars]

    results.append({
        "#":             i,
        "Comentario":    comment,
        "Estrellas":     stars,
        "Sentimiento":   f"{emoji} {label}",
        "Score (%)": score,
    })

    print(f"[{i:02d}] {comment[:65]}{'...' if len(comment)>65 else ''}")
    print(f"      → {emoji} {label}  |  Confianza: {score}%\n")

df = pd.DataFrame(results)
print("Análisis completado")
# Out:
#  Analizando comentarios...
#
# [01] ¿quién en 2025 recordando este temazo?
#       → ⭐ Muy Negativo / Odio  |  Confianza: 29.38%
#
# [02] Vengo a recordar cuando eramos felices sin darnos cuenta
#       → ⭐⭐⭐⭐⭐ Muy Positivo / Excelente  |  Confianza: 52.87%
#
# [03] Quien después de la presentación de la velada
#       → ⭐ Muy Negativo / Odio  |  Confianza: 23.62%
#
# [04] hace 10 años nuestras vidas fueron cambiadas 🥹
#       → ⭐⭐⭐⭐⭐ Muy Positivo / Excelente  |  Confianza: 40.05%
#
# [05] Youtube no te lo recomendó, tú viniste a escucharlo de nuevo para...
#       → ⭐ Muy Negativo / Odio  |  Confianza: 66.08%
#
# [06] YA ES PAPÁ
# BEBE LO LOGRAMOS
#       → ⭐⭐⭐⭐⭐ Muy Positivo / Excelente  |  Confianza: 53.3%
#
# [07] "Con tu perrito Curly"
# Hagamos que esto quede inmortalizado por l...
#       → ⭐⭐⭐⭐⭐ Muy Positivo / Excelente  |  Confianza: 37.55%
#
# [08] ¡¡¡¡HOY SE CUMPLEN 10 AÑOS DEL RAP DE FERNANFLOO!!!!
# GRACIAS - LU...
#       → ⭐⭐⭐⭐⭐ Muy Positivo / Excelente  |  Confianza: 74.49%
#
# [09] Regrese a escuchar este temazo después de su boda ️
#       → ⭐⭐⭐⭐⭐ Muy Positivo / Excelente  |  Confianza: 29.91%
#
# [10] Casi 5 años de alegria, solo quisiera volver al pasado :(
#       → ⭐⭐⭐⭐⭐ Muy Positivo / Excelente  |  Confianza: 49.62%
#
# [11] Que es más fácil
# Ignorar:aprenderse la tabla del 1
# Like: aprende...
#       → ⭐⭐⭐ Neutral / Ambivalente  |  Confianza: 22.93%
#
# [12] y pensar que ya cumplió 10 años el video... estamos viejos
#       → ⭐⭐⭐⭐⭐ Muy Positivo / Excelente  |  Confianza: 43.81%
#
# [13] Top 5 obras maestras que no necesitan un remake para ser mejor:
#       → ⭐⭐⭐⭐⭐ Muy Positivo / Excelente  |  Confianza: 92.14%
#
# [14] Mi mamá: que escuchas
# Yo: con lo crecí en mi infancia
#       → ⭐⭐⭐⭐⭐ Muy Positivo / Excelente  |  Confianza: 50.16%
#
# [15] Cómo olvidar cuando los comentarios no eran un calendario:')
#       → ⭐⭐⭐⭐⭐ Muy Positivo / Excelente  |  Confianza: 39.61%
#
# [16] Alguien en 2026?
#       → ⭐ Muy Negativo / Odio  |  Confianza: 55.1%
#
# [17] 2016: temazo
# 2019: joya de YouTube
# 2024: mi infancia
# 2025: himno ...
#       → ⭐⭐⭐⭐⭐ Muy Positivo / Excelente  |  Confianza: 36.85%
#
# [18] La época dorada de Youtube
#       → ⭐⭐⭐⭐⭐ Muy Positivo / Excelente  |  Confianza: 37.34%
#
# [19] Youtube no te lo recomendó . Tu lo fuiste a buscar para escuchar ...
#       → ⭐ Muy Negativo / Odio  |  Confianza: 71.94%
#
# [20] Ya 10 años
#       → ⭐⭐⭐⭐⭐ Muy Positivo / Excelente  |  Confianza: 51.16%
#
# [21] Acá es donde me dijeron que los dioses vienen a derramar sus lágr...
#       → ⭐ Muy Negativo / Odio  |  Confianza: 24.91%
#
# [22] YouTube le pone restricción de edad*
# Yo: Charles, el mundo ya no ...
#       → ⭐ Muy Negativo / Odio  |  Confianza: 50.8%
#
# [23] A mi me jode, que venga youtube y le ponga restricción de edad a ...
#       → ⭐⭐⭐⭐⭐ Muy Positivo / Excelente  |  Confianza: 25.18%
#
# [24] El rap de fernanfloo le gana a toda la carrera de todos los regue...
#       → ⭐⭐⭐⭐⭐ Muy Positivo / Excelente  |  Confianza: 68.97%
#
# [25] "Un hombre regresa al lugar donde alguna vez fue feliz "
#       → ⭐ Muy Negativo / Odio  |  Confianza: 23.27%
#
# [26] ¿Eres uno de esos héroes verdad?...
#
# Fernanfloo: Lo fui una vez....
#       → ⭐ Muy Negativo / Odio  |  Confianza: 47.66%
#
# [27] 10 años de magia
#       → ⭐⭐⭐⭐⭐ Muy Positivo / Excelente  |  Confianza: 67.8%
#
# [28] Aquí los q vinieron porque escucharon "antifloo" y les dio ganas ...
#       → ⭐⭐⭐⭐⭐ Muy Positivo / Excelente  |  Confianza: 50.84%
#
# [29] Hippies, nerds, ricos, pobres, populares, otakus, emos y normies,...
#       → ⭐⭐⭐⭐⭐ Muy Positivo / Excelente  |  Confianza: 36.44%
#
# [30] Nunca voy a olvidar cuando ponía la tv con mis hermanos, veíamos ...
#       → ⭐⭐⭐⭐⭐ Muy Positivo / Excelente  |  Confianza: 50.66%
#
# [31] Ya somos 50 millones ️
#       → ⭐ Muy Negativo / Odio  |  Confianza: 38.29%
#
# [32] No puedo creer que conocí a este gran Youtube en la primaria, el ...
#       → ⭐⭐⭐⭐⭐ Muy Positivo / Excelente  |  Confianza: 59.62%
#
# [33] Por fin alguien lo ve en 2018
#       → ⭐⭐⭐ Neutral / Ambivalente  |  Confianza: 22.25%
#
# [34] Uno siempre vuelve al lugar donde fue feliz...
#       → ⭐⭐⭐⭐⭐ Muy Positivo / Excelente  |  Confianza: 60.32%
#
# [35] Hoy se cumplen 10 años, quien más vino a recordar ?
#       → ⭐⭐⭐⭐⭐ Muy Positivo / Excelente  |  Confianza: 53.54%
#
# [36] Todos: una obra maestra...
#
# YouTube: ReStRiCcion D Edad
#       → ⭐⭐⭐⭐⭐ Muy Positivo / Excelente  |  Confianza: 56.17%
#
# [37] Objetivo: Ver los comentarios hace 4 años
# Obstaculo: Personas que...
#       → ⭐⭐⭐ Neutral / Ambivalente  |  Confianza: 28.5%
#
# [38] Solo los olds ven el antiguo diseño de las placas
#       → ⭐⭐⭐ Neutral / Ambivalente  |  Confianza: 31.2%
#
# [39] Está joya ya cumplió 10 años
#       → ⭐⭐⭐⭐⭐ Muy Positivo / Excelente  |  Confianza: 67.48%
#
# [40] Si Fernan entra con esto a la Velada, será una locura
#       → ⭐⭐⭐ Neutral / Ambivalente  |  Confianza: 27.9%
#
# Análisis completado

# %%
dist = df["Estrellas"].value_counts().sort_index()
dist = dist.reindex(range(1, 6), fill_value=0)


import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
colores = ['#d73027', '#fc8d59', '#fee090', '#91bfdb', '#4575b4']
barras = plt.bar(dist.index, dist.values, color=colores)

etiquetas = [f"{i} estrella" if i == 1 else f"{i} estrellas" for i in dist.index]
plt.xticks(dist.index, etiquetas)

plt.title("Distribución de Calificaciones (Estrellas)", fontsize=14)
plt.xlabel("Nivel de sentimiento", fontsize=12)
plt.ylabel("Número de comentarios", fontsize=12)

max_y = max(dist.values) if max(dist.values) > 0 else 1
plt.ylim(0, max_y * 1.1)

for i, v in enumerate(dist.values):
    if v > 0:
        plt.text(dist.index[i], v + (max_y * 0.03), str(v), ha='center', va='bottom', fontsize=10)

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
dist = df["Estrellas"].value_counts().sort_index()
dist = dist.reindex(range(1, 6), fill_value=0)

total = len(df)
avg = df["Estrellas"].mean()

print("\n  Distribución por estrellas:")
for s in range(1, 6):
    n = dist.loc[s]
    print(f"  {s} estrella{'s' if s>1 else ''} : {n}")

import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
colores = ['#d73027', '#fc8d59', '#fee090', '#91bfdb', '#4575b4']
plt.bar(dist.index, dist.values, color=colores)

etiquetas = [f"{i} estrella" if i == 1 else f"{i} estrellas" for i in dist.index]
plt.xticks(dist.index, etiquetas)

plt.title("Distribución de Calificaciones (Estrellas)", fontsize=14)
plt.xlabel("Nivel de sentimiento", fontsize=12)
plt.ylabel("Número de comentarios", fontsize=12)

max_y = max(dist.values) if max(dist.values) > 0 else 1
plt.ylim(0, max_y * 1.1)

for i, v in enumerate(dist.values):
    if v > 0:
        plt.text(dist.index[i], v + (max_y * 0.03), str(v), ha='center', va='bottom', fontsize=10)

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
#   Distribución por estrellas:
#   1 estrella : 10
#   2 estrellas : 0
#   3 estrellas : 5
#   4 estrellas : 0
#   5 estrellas : 25
